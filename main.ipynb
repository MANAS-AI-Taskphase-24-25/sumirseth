# %% [markdown]
# # Linear Regression for Manas Task One

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import math

# %% [markdown]
# ### Initial Loading

# %%
data = pd.read_csv("Train.csv")
test_data = pd.read_csv("Test.csv")
data.drop(columns=['Unnamed: 0'], inplace=True)
data.head()
# Out:
#                                          Name   Location  Year  \
# 0         Tata Tiago 1.2 Revotron XZ WO Alloy  Hyderabad  2017
# 1  Mahindra TUV 300 2015-2019 mHAWK100 T8 AMT      Kochi  2017
# 2      Skoda Rapid 2013-2016 1.6 MPI Ambition     Mumbai  2014
# 3                     Tata Indica V2 DLS BSII     Jaipur  2007
# 4        Tata Manza Club Class Quadrajet90 LX     Mumbai  2013
#
#    Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage   Engine  \
# 0              16500    Petrol       Manual      First  23.84 kmpl  1199 CC
# 1              47357    Diesel    Automatic      First  18.49 kmpl  1493 CC
# 2              35000    Petrol       Manual      First   15.0 kmpl  1598 CC
# 3             200000    Diesel       Manual     Second   17.2 kmpl  1396 CC
# 4              64000    Diesel       Manual     Second  21.02 kmpl  1248 CC
#
#         Power  Seats  Price
# 0      84 bhp    5.0   5.00
# 1     100 bhp    7.0   8.37
# 2  103.52 bhp    5.0   4.50
# 3    53.5 bhp    5.0   0.85
# 4   88.76 bhp    5.0   2.65

# %%
data.describe()
# Out:
#               Year  Kilometers_Driven        Seats        Price
# count  3750.000000        3750.000000  3718.000000  3750.000000
# mean   2013.313333       58128.811733     5.277838     9.498632
# std       3.264250       40343.978048     0.806216    11.207836
# min    1998.000000        1000.000000     2.000000     0.440000
# 25%    2011.000000       34000.000000     5.000000     3.500000
# 50%    2014.000000       53000.000000     5.000000     5.665000
# 75%    2016.000000       73157.750000     5.000000     9.900000
# max    2019.000000      775000.000000    10.000000   160.000000

# %%
data.isnull().sum()
# Out:
# Name                  0
# Location              0
# Year                  0
# Kilometers_Driven     0
# Fuel_Type             0
# Transmission          0
# Owner_Type            0
# Mileage               1
# Engine               28
# Power                28
# Seats                32
# Price                 0
# dtype: int64

# %% [markdown]
# ### Cleaning Up the Data

# %%
def processData(column, unit):
    return column.str.replace(" " + unit, "", regex=False).replace("null", None).astype(float)

# %%
data["Mileage"] = processData(data["Mileage"], "kmpl")
data["Power"] = processData(data["Power"], "bhp")
data["Engine"] = processData(data["Engine"], "CC")

# %%
X_train = data.drop(columns=['Price', 'Name'])
y_train = data['Price']

# %%
X_train = X_train.apply(pd.to_numeric, errors='coerce')

# print(X_train.isnull().sum())
X_train
# Out:
#       Location  Year  Kilometers_Driven  Fuel_Type  Transmission  Owner_Type  \
# 0          NaN  2017              16500        NaN           NaN         NaN
# 1          NaN  2017              47357        NaN           NaN         NaN
# 2          NaN  2014              35000        NaN           NaN         NaN
# 3          NaN  2007             200000        NaN           NaN         NaN
# 4          NaN  2013              64000        NaN           NaN         NaN
# ...        ...   ...                ...        ...           ...         ...
# 3745       NaN  2009             150000        NaN           NaN         NaN
# 3746       NaN  2012              85000        NaN           NaN         NaN
# 3747       NaN  2007              55100        NaN           NaN         NaN
# 3748       NaN  2014              77500        NaN           NaN         NaN
# 3749       NaN  2012              40000        NaN           NaN         NaN
#
#       Mileage  Engine   Power  Seats
# 0       23.84  1199.0   84.00    5.0
# 1       18.49  1493.0  100.00    7.0
# 2       15.00  1598.0  103.52    5.0
# 3       17.20  1396.0   53.50    5.0
# 4       21.02  1248.0   88.76    5.0
# ...       ...     ...     ...    ...
# 3745    11.00  2993.0  235.00    5.0
# 3746    11.79  2179.0  120.00    7.0
# 3747    18.90   998.0   67.10    5.0
# 3748    20.45  1461.0   83.80    5.0
# 3749    18.90   998.0   67.10    5.0
#
# [3750 rows x 10 columns]

# %% [markdown]
# ## Main Processing for LR

# %%
def normalise(x):
    return (x - x.mean()) / x.std()

# %%
class LinearRegression:
    def __init__(self, alpha=0.0001, n_iter=1000, rc=10):
        self.alpha = alpha
        self.n_iter = n_iter
        self.rc = rc
        self.w = None
        self.b = None
        self.cost = []

    def fit(self, X, y):
        n_samples, n_features = X.shape
        self.w = np.zeros(n_features)
        self.b = 0

        for _ in range(self.n_iter):
            y_pred = np.dot(X, self.w) + self.b
            dw  = (1/n_samples)*(  np.dot(X.T , y_pred  - y)) + (self.rc/n_samples)*(self.weights)
            db  = (1/n_samples)*np.sum(y_pred  - y )

            self.w -= self.alpha * dw
            self.b -= self.alpha * db

            cost = (1 / (2 * n_samples)) * np.sum((y_pred - y) ** 2) + \
                   (self.rc / (2 * n_samples)) * np.sum(self.w ** 2)
            self.costs.append(cost)
    
    def predict(self, X):
        predictions = np.dot(X, self.w) + self.b
        return predictions

# %%
def MSE(y_true, y_pred):
    return np.mean((y_true - y_pred) ** 2)

# %%
def RMSE(y_true, y_pred):
    return np.sqrt(np.mean((y_true - y_pred) ** 2))

# %%
def R2(y_true, y_pred):
    tv = np.sum((y_true - np.mean(y_true))**2)
    pv = np.sum((y_true - np.mean(y_pred))**2)
    return 1 - (pv/tv)

# %% [markdown]
# ### Preparing for Implementing the Algorithm

# %%
X_train = pd.DataFrame(normalise(X_train))
y_train = pd.DataFrame(y_train)

X_train = X_train.apply(pd.to_numeric, errors='coerce')
y_train = y_train.apply(pd.to_numeric, errors='coerce')

X_train = X_train.fillna(X_train.mean())
y_train = y_train.fillna(y_train.mean())

X_train = np.where(np.isnan(X_train), np.nanmean(X_train, axis=0), X_train)
# Out:
# C:\Users\clash\AppData\Local\Temp\ipykernel_1908\2558264724.py:10: RuntimeWarning: Mean of empty slice
#   X_train = np.where(np.isnan(X_train), np.nanmean(X_train, axis=0), X_train)
